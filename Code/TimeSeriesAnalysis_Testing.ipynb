# %% [markdown]
# # **Loading Packages**
# ____

# %%
import numpy as np
import pandas as pd
import os

from fredapi import Fred

import matplotlib.pyplot as plt

from scipy import stats
from scipy.special import inv_boxcox
from scipy.stats import yeojohnson

from pmdarima.arima import auto_arima
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %% [markdown]
# # **Loading Data**
# ____

# %%
os.chdir('/Users/dannyhogan/Desktop/ST-498')
df_UK = pd.read_csv("Data/MacroVariablesUK.csv", index_col=0)
df_US = pd.read_csv("Data/MacroVariables_US_Q.csv", index_col=0)
#UK_GDP = df_UK['rGDP']

# %% [markdown]
# # **Time Series with py file**
# ______

# %%
os.chdir('/Users/dannyhogan/Desktop/ST-498/Code')

# %%
from Optimal_SARIMA import run_sarima_pipeline


results, comparisons = run_sarima_pipeline(
    df_US,
    m=4,
    n_periods=20,
    plot=True,
    save_dir='sarima_plots',
)
# Out:
# ──────────────────────────────────────────────────────────────────────────────────────────
#   AUTO-DETECTED SERIES CONFIGURATION
# ──────────────────────────────────────────────────────────────────────────────────────────
#   Column                         Regime                 d   D  Seas max_p Transforms
#   ─────────────────────────────────────────────────────────────────────────────────────
#   us_house_price_idx             persistent-bounded     ?   0     ✓     3   none
#   us_cpi                         persistent-bounded     ?   0     ✓     3   none, yeo-johnson
#   us_unemployment                stationary-level       0   0     ✓     3   none, yeo-johnson
#   us_consumer_confidence         stationary-level       0   0     ✗     3   none, yeo-johnson
#   us_real_gdp                    non-stationary         ?   0     ✗     3   none, log, boxcox
#   us_gdp_yoy_growth              persistent-bounded     ?   0     ✗     3   none, yeo-johnson
#   us_bond_yield_10y              persistent-bounded (ovr)   ?   0     ✗     3   none, yeo-johnson
#   us_bond_yield_1y               persistent-bounded (ovr)   ?   0     ✗     3   none, yeo-johnson
#   us_term_spread                 stationary-level       0   0     ✓     3   none
#   us_reer                        persistent-bounded     ?   0     ✓     3   none
#   us_reer_log_ret                return/growth          0   0     ✗     5   none
#   us_oil_price                   non-stationary         ?   0     ✗     3   none, log, boxcox
#   us_oil_log_ret                 return/growth          0   0     ✗     5   none
#   us_credit                      non-stationary         ?   ?     ✓     3   none, log, boxcox
#   us_credit_qoq_growth           persistent-bounded     ?   0     ✓     3   none, yeo-johnson
#   us_credit_yoy_growth           persistent-bounded     ?   0     ✓     3   none, yeo-johnson
#   us_industrial_production       non-stationary         ?   0     ✗     3   none, log, boxcox
#   us_vix                         stationary-level       0   0     ✗     3   none, yeo-johnson
#   us_vix_log_ret                 return/growth          0   0     ✗     5   none
#   us_delinquency_rate            persistent-bounded     ?   0     ✓     3   none
#   us_sp500_close                 non-stationary         ?   0     ✗     3   none, log, boxcox
#   us_sp500_log_ret               return/growth          0   0     ✗     5   none
#
#
# ============================================================
#   Processing: us_house_price_idx
#   Regime: persistent-bounded  |  d=None  D=0  seasonal=True  max_p=3
#   Transforms: ['none']
# ============================================================
# transformation        aic        bic  cv_rmse   cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h    skew  kurtosis
#           none 491.587209 518.844583 2.940474 2.459065              5 (3, 1, 0)   (1, 0, 2, 4)      3.762489  0.8649      0.0   0.007 14.0874  206.7929
#
#   ✓ Best: [none]  SARIMA(3, 1, 0)x(1, 0, 2, 4)  AIC=491.59  CV-RMSE=2.9405
#
# ============================================================
#   Processing: us_cpi
#   Regime: persistent-bounded  |  d=None  D=0  seasonal=True  max_p=3
#   Transforms: ['none', 'yeo-johnson']
# ============================================================
# transformation        aic        bic  cv_rmse   cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h    skew  kurtosis
#           none 430.152206 459.173175 1.147225 0.998095              5 (3, 1, 1)   (1, 0, 2, 4)      0.508724  0.9210      0.0     0.0 -1.0589   10.1346
#    yeo-johnson 230.913941 249.052047 1.854866 1.616888              5 (1, 1, 2)   (0, 0, 1, 4)      0.373488  0.9221      0.0     0.0  1.6928   27.5256
#
#   ✓ Best: [none]  SARIMA(3, 1, 1)x(1, 0, 2, 4)  AIC=430.15  CV-RMSE=1.1472
#
# ============================================================
#   Processing: us_unemployment
#   Regime: stationary-level  |  d=0  D=0  seasonal=True  max_p=3
#   Transforms: ['none', 'yeo-johnson']
# ============================================================
# transformation        aic        bic  cv_rmse   cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h   skew  kurtosis
#    yeo-johnson 158.467469 173.063366 0.452199 0.402504              5 (2, 0, 1)   (0, 0, 0, 4)      0.316301  0.8527      0.0     0.0 6.2673   87.0912
#           none 598.794713 609.741635 0.629660 0.576256              5 (1, 0, 0)   (0, 0, 0, 4)      0.688252  0.8828      0.0     0.0 7.5561  106.5912
#
#   ✓ Best: [yeo-johnson]  SARIMA(2, 0, 1)x(0, 0, 0, 4)  AIC=158.47  CV-RMSE=0.4522
#
# ============================================================
#   Processing: us_consumer_confidence
#   Regime: stationary-level  |  d=0  D=0  seasonal=False  max_p=3
#   Transforms: ['none', 'yeo-johnson']
# ============================================================
# transformation        aic        bic  cv_rmse   cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h   skew  kurtosis
#    yeo-johnson  25.519105  40.115002 0.753035 0.710088              5 (2, 0, 1)   (0, 0, 0, 0)      0.266001  0.7574      0.0  0.0843 0.7148   10.5418
#           none 299.896314 318.141185 0.872651 0.838831              5 (2, 0, 1)   (0, 0, 0, 0)      0.419803  0.6355      0.0  0.0002 0.6625   13.8413
#
#   ✓ Best: [yeo-johnson]  SARIMA(2, 0, 1)x(0, 0, 0, 0)  AIC=25.52  CV-RMSE=0.7530
#
# ============================================================
#   Processing: us_real_gdp
#   Regime: non-stationary  |  d=None  D=0  seasonal=False  max_p=3
#   Transforms: ['none', 'log', 'boxcox']
# ============================================================
# transformation          aic          bic    cv_rmse     cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h    skew  kurtosis
#            log -1944.309663 -1929.299373 194.403996 181.727268              5 (2, 1, 0)   (0, 0, 0, 0)      0.432211  0.9276      0.0  0.1007 17.6749  313.6030
#         boxcox  -578.098910  -570.593765 202.607141 183.422309              5 (0, 1, 0)   (0, 0, 0, 0)      1.227752  0.6598      0.0  0.0000 17.5279  310.1732
#           none  4036.397128  4047.645307 223.567786 204.517870              5 (0, 2, 2)   (0, 0, 0, 0)    200.863955  0.9051      0.0  0.0000  1.6937   70.0287
#
#   ✓ Best: [log]  SARIMA(2, 1, 0)x(0, 0, 0, 0)  AIC=-1944.31  CV-RMSE=194.4040
#
# ============================================================
#   Processing: us_gdp_yoy_growth
#   Regime: persistent-bounded  |  d=None  D=0  seasonal=False  max_p=3
#   Transforms: ['none', 'yeo-johnson']
# ============================================================
# transformation         aic         bic  cv_rmse   cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h   skew  kurtosis
#    yeo-johnson  593.650911  601.130497 2.864548 2.614053              5 (1, 1, 0)   (0, 0, 0, 0)      0.624555  0.8742      0.0  0.4869 0.2752   13.6234
#           none 1195.356426 1202.836011 2.866195 2.615821              5 (1, 1, 0)   (0, 0, 0, 0)      1.649514  0.8774      0.0  0.3443 0.2191   12.8213
#
#   ✓ Best: [yeo-johnson]  SARIMA(1, 1, 0)x(0, 0, 0, 0)  AIC=593.65  CV-RMSE=2.8645
#
# ============================================================
#   Processing: us_bond_yield_10y
#   Regime: persistent-bounded (ovr)  |  d=None  D=0  seasonal=False  max_p=3
#   Transforms: ['none', 'yeo-johnson']
# ============================================================
# transformation         aic         bic  cv_rmse   cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h    skew  kurtosis
#    yeo-johnson -129.323601 -125.653720 0.651294 0.601025              5 (0, 1, 0)   (0, 0, 0, 0)      0.199162  0.4455      0.0  0.0000 -0.5001    5.7156
#           none  492.776442  496.446323 0.652957 0.602705              5 (0, 1, 0)   (0, 0, 0, 0)      0.592621  0.4140      0.0  0.0122 -0.0055    8.5646
#
#   ✓ Best: [yeo-johnson]  SARIMA(0, 1, 0)x(0, 0, 0, 0)  AIC=-129.32  CV-RMSE=0.6513
#
# ============================================================
#   Processing: us_bond_yield_1y
#   Regime: persistent-bounded (ovr)  |  d=None  D=0  seasonal=False  max_p=3
#   Transforms: ['none', 'yeo-johnson']
# ============================================================
# transformation        aic        bic  cv_rmse   cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h    skew  kurtosis
#           none 684.123110 698.288164 0.934205 0.823238              5 (3, 1, 0)   (0, 0, 0, 0)      0.929456  0.7929      0.0  0.0000 -1.3510   16.5534
#    yeo-johnson -29.586881 -26.045618 0.964800 0.857200              5 (0, 1, 0)   (0, 0, 0, 0)      0.229204  0.4327      0.0  0.0001 -1.0754    9.8994
#
#   ✓ Best: [none]  SARIMA(3, 1, 0)x(0, 0, 0, 0)  AIC=684.12  CV-RMSE=0.9342
#
# ============================================================
#   Processing: us_term_spread
#   Regime: stationary-level  |  d=0  D=0  seasonal=True  max_p=3
#   Transforms: ['none']
# ============================================================
# transformation        aic        bic  cv_rmse   cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h   skew  kurtosis
#           none 429.991062 444.171771 0.605682 0.539555              5 (2, 0, 0)   (0, 0, 0, 4)      0.551212  0.9847      0.0     0.0 1.1365   11.2584
#
#   ✓ Best: [none]  SARIMA(2, 0, 0)x(0, 0, 0, 4)  AIC=429.99  CV-RMSE=0.6057
#
# ============================================================
#   Processing: us_reer
#   Regime: persistent-bounded  |  d=None  D=0  seasonal=True  max_p=3
#   Transforms: ['none']
# ============================================================
# transformation        aic        bic  cv_rmse   cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h   skew  kurtosis
#           none 579.574797 582.418984 4.042677 3.596195              5 (0, 1, 0)   (0, 0, 0, 4)      8.134422  0.4838   0.5718  0.3703 9.7911   105.933
#
#   ✓ Best: [none]  SARIMA(0, 1, 0)x(0, 0, 0, 4)  AIC=579.57  CV-RMSE=4.0427
#
# ============================================================
#   Processing: us_reer_log_ret
#   Regime: return/growth  |  d=0  D=0  seasonal=False  max_p=5
#   Transforms: ['none']
# ============================================================
# transformation         aic        bic  cv_rmse   cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h    skew  kurtosis
#           none -576.129497 -573.28531  0.02263 0.019914              5 (0, 0, 0)   (0, 0, 0, 0)      0.024896  0.3735   0.4971  0.6535 -0.1081    2.5337
#
#   ✓ Best: [none]  SARIMA(0, 0, 0)x(0, 0, 0, 0)  AIC=-576.13  CV-RMSE=0.0226
#
# ============================================================
#   Processing: us_oil_price
#   Regime: non-stationary  |  d=None  D=0  seasonal=False  max_p=3
#   Transforms: ['none', 'log', 'boxcox']
# ============================================================
# transformation         aic         bic   cv_rmse    cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h    skew  kurtosis
#         boxcox   23.259997   32.466710 15.808877 14.554271              5 (1, 1, 1)   (0, 0, 0, 0)      0.321170  0.8544      0.0  0.0235  2.1514   26.3002
#            log  -52.573795  -43.367082 15.900658 14.639904              5 (1, 1, 1)   (0, 0, 0, 0)      0.270742  0.8221      0.0  0.0587  3.2492   35.7421
#           none 1210.881293 1220.088005 16.185607 14.279364              5 (2, 1, 0)   (0, 0, 0, 0)     10.714464  0.9756      0.0  0.0000 -1.0337    8.8716
#
#   ✓ Best: [boxcox]  SARIMA(1, 1, 1)x(0, 0, 0, 0)  AIC=23.26  CV-RMSE=15.8089
#
# ============================================================
#   Processing: us_oil_log_ret
#   Regime: return/growth  |  d=0  D=0  seasonal=False  max_p=5
#   Transforms: ['none']
# ============================================================
# transformation        aic        bic  cv_rmse   cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h    skew  kurtosis
#           none -52.573795 -43.367082 0.152548 0.125742              5 (1, 0, 1)   (0, 0, 0, 0)      0.200784  0.8221      0.0  0.0587 -1.2082   10.4301
#
#   ✓ Best: [none]  SARIMA(1, 0, 1)x(0, 0, 0, 0)  AIC=-52.57  CV-RMSE=0.1525
#
# ============================================================
#   Processing: us_credit
#   Regime: non-stationary  |  d=None  D=None  seasonal=True  max_p=3
#   Transforms: ['none', 'log', 'boxcox']
# ============================================================
# transformation          aic          bic    cv_rmse     cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h    skew  kurtosis
#           none  3749.922847  3764.971052 414.802392 377.117129              5 (0, 2, 1)   (1, 0, 1, 4)     86.662143  0.6318      0.0  0.0000  0.3785   21.8795
#         boxcox -1779.767062 -1764.718856 464.167374 399.370959              5 (1, 2, 0)   (1, 0, 1, 4)      0.364062  0.7039      0.0  0.0008 11.3810  218.9847
#            log -2385.688855 -2359.354495 481.931949 410.904363              5 (2, 2, 0)   (2, 0, 2, 4)      0.277321  0.9464      0.0  0.0990 11.3409  218.8479
#
#   ✓ Best: [none]  SARIMA(0, 2, 1)x(1, 0, 1, 4)  AIC=3749.92  CV-RMSE=414.8024
#
# ============================================================
#   Processing: us_credit_qoq_growth
#   Regime: persistent-bounded  |  d=None  D=0  seasonal=True  max_p=3
#   Transforms: ['none', 'yeo-johnson']
# ============================================================
# transformation        aic        bic  cv_rmse   cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h   skew  kurtosis
#           none 543.288942 565.861251 0.546508 0.462678              5 (1, 1, 2)   (1, 0, 1, 4)      0.604816  0.8278      0.0  0.2412 0.8518   11.2420
#    yeo-johnson 490.626278 505.674483 0.574336 0.488015              5 (1, 1, 0)   (1, 0, 1, 4)      0.528902  0.9672      0.0  0.0653 0.0307    5.5698
#
#   ✓ Best: [none]  SARIMA(1, 1, 2)x(1, 0, 1, 4)  AIC=543.29  CV-RMSE=0.5465
#
# ============================================================
#   Processing: us_credit_yoy_growth
#   Regime: persistent-bounded  |  d=None  D=0  seasonal=True  max_p=3
#   Transforms: ['none', 'yeo-johnson']
# ============================================================
# transformation         aic         bic  cv_rmse   cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h    skew  kurtosis
#           none  566.974347  593.242355 1.081867 0.929901              5 (3, 1, 1)   (0, 0, 1, 4)      1.126473  0.7764      0.0  0.1416 11.0171  168.8384
#    yeo-johnson -278.685670 -256.170234 1.104800 0.954678              5 (3, 1, 1)   (0, 0, 1, 4)      0.203867  0.7602      0.0  0.0209  5.0389   63.6343
#
#   ✓ Best: [none]  SARIMA(3, 1, 1)x(0, 0, 1, 4)  AIC=566.97  CV-RMSE=1.0819
#
# ============================================================
#   Processing: us_industrial_production
#   Regime: non-stationary  |  d=None  D=0  seasonal=False  max_p=3
#   Transforms: ['none', 'log', 'boxcox']
# ============================================================
# transformation          aic          bic  cv_rmse   cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h    skew  kurtosis
#           none  1137.737274  1149.907626 0.966804 0.808520              5 (1, 1, 0)   (0, 0, 0, 0)      0.933786  0.7501      0.0     0.0 -0.2805   14.5492
#         boxcox  -815.414804  -803.244452 1.024977 0.814221              5 (1, 1, 0)   (0, 0, 0, 0)      0.131709  0.8660      0.0     0.0  7.2845  112.4737
#            log -1513.341967 -1484.944479 1.761838 1.487962              5 (3, 1, 2)   (0, 0, 0, 0)      0.083132  0.8609      0.0     0.0 13.7347  249.0787
#
#   ✓ Best: [none]  SARIMA(1, 1, 0)x(0, 0, 0, 0)  AIC=1137.74  CV-RMSE=0.9668
#
# ============================================================
#   Processing: us_vix
#   Regime: stationary-level  |  d=0  D=0  seasonal=False  max_p=3
#   Transforms: ['none', 'yeo-johnson']
# ============================================================
# transformation        aic        bic  cv_rmse   cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h   skew  kurtosis
#    yeo-johnson 326.769354 335.678794 4.743395 4.160613              5 (1, 0, 1)   (0, 0, 0, 0)      0.738315  0.9118      0.0  0.0504 0.8861    4.0625
#           none 947.709671 959.588924 5.116585 4.470381              5 (1, 0, 1)   (0, 0, 0, 0)      6.335662  0.9032      0.0  0.0267 2.5836   12.4241
#
#   ✓ Best: [yeo-johnson]  SARIMA(1, 0, 1)x(0, 0, 0, 0)  AIC=326.77  CV-RMSE=4.7434
#
# ============================================================
#   Processing: us_vix_log_ret
#   Regime: return/growth  |  d=0  D=0  seasonal=False  max_p=5
#   Transforms: ['none']
# ============================================================
# transformation       aic       bic  cv_rmse   cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h   skew  kurtosis
#           none 36.842022 42.767711 0.247061 0.221756              5 (0, 0, 1)   (0, 0, 0, 0)      0.272409   0.739      0.0  0.0415 1.3395    6.1471
#
#   ✓ Best: [none]  SARIMA(0, 0, 1)x(0, 0, 0, 0)  AIC=36.84  CV-RMSE=0.2471
#
# ============================================================
#   Processing: us_delinquency_rate
#   Regime: persistent-bounded  |  d=None  D=0  seasonal=True  max_p=3
#   Transforms: ['none']
# ============================================================
# transformation        aic        bic  cv_rmse   cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h   skew  kurtosis
#           none -90.628871 -75.956501 0.271848 0.245071              5 (1, 1, 0)   (2, 0, 1, 4)      0.476407  0.4562      0.0  0.1414 9.6078  106.0633
#
#   ✓ Best: [none]  SARIMA(1, 1, 0)x(2, 0, 1, 4)  AIC=-90.63  CV-RMSE=0.2718
#
# ============================================================
#   Processing: us_sp500_close
#   Regime: non-stationary  |  d=None  D=0  seasonal=False  max_p=3
#   Transforms: ['none', 'log', 'boxcox']
# ============================================================
# transformation         aic         bic    cv_rmse     cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h    skew  kurtosis
#         boxcox -861.094711 -853.667245 582.962093 537.859915              5 (0, 1, 0)   (0, 0, 0, 0)      0.161925  0.2351      0.0  0.4841 14.0479  229.4659
#            log -681.690889 -674.263423 603.201468 557.753653              5 (0, 1, 0)   (0, 0, 0, 0)      0.180121  0.3022      0.0  0.3307 12.5898  199.4400
#           none 3755.257977 3766.389258 686.059412 635.287971              5 (0, 2, 1)   (0, 0, 0, 0)    119.442081  0.8375      0.0  0.0000 -1.2600   17.9954
#
#   ✓ Best: [boxcox]  SARIMA(0, 1, 0)x(0, 0, 0, 0)  AIC=-861.09  CV-RMSE=582.9621
#
# ============================================================
#   Processing: us_sp500_log_ret
#   Regime: return/growth  |  d=0  D=0  seasonal=False  max_p=5
#   Transforms: ['none']
# ============================================================
# transformation         aic         bic  cv_rmse  cv_mae  cv_folds_used     order seasonal_order  residual_std  prob_q  prob_jb  prob_h    skew  kurtosis
#           none -681.690889 -674.263423 0.067475 0.05909              5 (0, 0, 0)   (0, 0, 0, 0)      0.078176  0.3022      0.0  0.3307 -0.9996    4.9317
#
#   ✓ Best: [none]  SARIMA(0, 0, 0)x(0, 0, 0, 0)  AIC=-681.69  CV-RMSE=0.0675
#   📊 Saved 22 plots → sarima_plots/

# %%
from VAR import run_var_vecm_pipeline

pipeline = run_var_vecm_pipeline(df_US, n_periods=20, max_lags=8, max_vars=8, plot=True)

# %% [markdown]
# # **Manual Modeling**
# ____

# %% [markdown]
# ## **GDP Model Selection:**

# %% [markdown]
# ### **SARIMA w/ Original Data**

# %%
model_auto = auto_arima(y=UK_GDP['rGDP'], start_P=0, 
                        start_q=0, m=4, information_criterion='aic')

# %%
print(model_auto)
# Out:
#  ARIMA(2,1,0)(0,0,1)[4] intercept

# %% [markdown]
# ### **SARIMA w/ Box-Cox Transformation**

# %%
UK_GDP['Transformed'], opt_lambda = stats.boxcox(UK_GDP['rGDP'])

model_auto_transformed = auto_arima(y=UK_GDP['Transformed'], start_p=0, 
                        start_q=0, m=4,start_P=0, start_Q=0, information_criterion='aic')

# %%
print(model_auto_transformed)
# Out:
#  ARIMA(0,1,1)(0,0,1)[4] intercept

# %% [markdown]
# ### **SARIMA w/ Log Transformation**

# %%
UK_GDP['Log_GDP'] = np.log(UK_GDP['rGDP'])

model_auto_log = auto_arima(y=UK_GDP['Log_GDP'], m=4,seasonal=True)

# %%
print(model_auto_log)

# %% [markdown]
# ### **Comparing Results**

# %%
print(model_auto.summary())
# Out:
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                  283
# Model:             SARIMAX(2, 1, 0)x(0, 0, [1], 4)   Log Likelihood               -2996.144
# Date:                             Sun, 08 Feb 2026   AIC                           6002.288
# Time:                                     14:58:36   BIC                           6020.497
# Sample:                                          0   HQIC                          6009.590
#                                              - 283
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   2800.3190    626.400      4.470      0.000    1572.598    4028.040
# ar.L1         -0.1721      0.013    -12.773      0.000      -0.199      -0.146
# ar.L2         -0.0829      0.045     -1.839      0.066      -0.171       0.005
# ma.S.L4       -0.0914      0.024     -3.876      0.000      -0.138      -0.045
# sigma2      9.794e+07      0.300   3.26e+08      0.000    9.79e+07    9.79e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.08   Jarque-Bera (JB):            188224.77
# Prob(Q):                              0.15   Prob(JB):                         0.00
# Heteroskedasticity (H):              17.28   Skew:                            -8.03
# Prob(H) (two-sided):                  0.00   Kurtosis:                       128.54
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.92e+22. Standard errors may be unstable.

# %%
print(model_auto_transformed.summary())
# Out:
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                                 y   No. Observations:                  283
# Model:             SARIMAX(0, 1, 1)x(0, 0, 1, 4)   Log Likelihood                -549.641
# Date:                           Sun, 08 Feb 2026   AIC                           1107.282
# Time:                                   17:05:08   BIC                           1121.850
# Sample:                               01-01-1955   HQIC                          1113.124
#                                     - 07-01-2025
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.4472      0.124      3.604      0.000       0.204       0.690
# ma.L1         -0.2575      0.017    -15.301      0.000      -0.291      -0.225
# ma.S.L4       -0.1302      0.036     -3.622      0.000      -0.201      -0.060
# sigma2         2.8858      0.051     56.662      0.000       2.786       2.986
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            159932.13
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               9.99   Skew:                            -8.09
# Prob(H) (two-sided):                  0.00   Kurtosis:                       118.54
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
print(model_auto_log.summary())

# %% [markdown]
# #### **Thoughts**
# ___
# The auto log model significantly outperforms box-cox and the original dataset, thus we will use the given model parameters from the auto-arima function for auto log.

# %% [markdown]
# ### **Fitting Final Model (GDP)**

# %%
forecast_log = model_auto_log.predict(n_periods=8)
forecast_from_log = np.exp(forecast_log)

forecast_index = pd.date_range(start=UK_GDP.index[-1], periods=9, freq='Q')[1:]

plt.figure(figsize=(14, 8))
recent_data = UK_GDP['GDP'].iloc[-40:]
plt.plot(recent_data.index, recent_data.values, label='Historical', linewidth=2)
plt.plot(forecast_index, forecast_from_log, label='Forecast (Log Transform)', 
         linewidth=2, color='purple', marker='o', markersize=8)
plt.title('UK GDP Forecast - Log Transformation')
plt.ylabel('GDP')
plt.xlabel('Date')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/ts/x847bxb170n3msnnpmdpjll00000gn/T/ipykernel_65218/1969432115.py:4: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   forecast_index = pd.date_range(start=UK_GDP.index[-1], periods=9, freq='Q')[1:]

# %% [markdown]
# Quick note: Claude was used below to help validate the model more

# %%
growth_rates = (np.diff(forecast_from_log) / forecast_from_log[:-1]) * 100
print("\nQuarter-to-Quarter Growth Rates:")
for i, rate in enumerate(growth_rates, 1):
    print(f"Q{i} to Q{i+1}: {rate:.3f}%")

print(f"\nGrowth rate std deviation: {np.std(growth_rates):.5f}%")
print("(Low std = nearly constant growth rate = exponential curve)")
# Out:
# Quarter-to-Quarter Growth Rates:
# Q1 to Q2: 0.549%
# Q2 to Q3: 0.598%
# Q3 to Q4: 0.615%
# Q4 to Q5: 0.548%
# Q5 to Q6: 0.562%
# Q6 to Q7: 0.562%
# Q7 to Q8: 0.562%
#
# Growth rate std deviation: 0.02355%
# (Low std = nearly constant growth rate = exponential curve)

# %%
UK_GDP['QoQ_Growth'] = UK_GDP['GDP'].pct_change() * 100

print("Historical Quarterly Growth Rates:")
print(f"\nLast 5 years (20 quarters):")
print(f"  Mean: {UK_GDP['QoQ_Growth'].iloc[-20:].mean():.3f}%")
print(f"  Std:  {UK_GDP['QoQ_Growth'].iloc[-20:].std():.3f}%")
print(f"  Min:  {UK_GDP['QoQ_Growth'].iloc[-20:].min():.3f}%")
print(f"  Max:  {UK_GDP['QoQ_Growth'].iloc[-20:].max():.3f}%")

print(f"\nLast 10 years (40 quarters):")
print(f"  Mean: {UK_GDP['QoQ_Growth'].iloc[-40:].mean():.3f}%")
print(f"  Std:  {UK_GDP['QoQ_Growth'].iloc[-40:].std():.3f}%")
print(f"  Min:  {UK_GDP['QoQ_Growth'].iloc[-40:].min():.3f}%")
print(f"  Max:  {UK_GDP['QoQ_Growth'].iloc[-40:].max():.3f}%")
# Out:
# Historical Quarterly Growth Rates:
#
# Last 5 years (20 quarters):
#   Mean: 0.734%
#   Std:  1.605%
#   Min:  -1.076%
#   Max:  6.982%
#
# Last 10 years (40 quarters):
#   Mean: 0.429%
#   Std:  4.383%
#   Min:  -19.906%
#   Max:  16.965%

# %% [markdown]
# We can see that the growth is fairly reasonable as a baseline model for GDP growth, being slighting above the 10 year average for quartly growth. However there are a few things to keep an eye on. First, is the convergence of the predicted growth, the last 3 predicted years are all predicted for .562% growth. We will need to adress this since our predictions should range out from 3-5 years. Second thing is the use of exodgenous variables. We may be able to get a better forecast of GDP by using additional variables. The final note is that the small std of our prediction is ok for our baseline secnario, but we will have to think about it as we predict various market conditions.

# %% [markdown]
# ## **CPI (Inflation)**

# %%
CPI = df[['cpi']].copy()

#Needed this to drop 2026 observation
CPI = CPI.dropna()

#Needed this for the YeoJohnson Transformation
    #Will look into what specifically it does, it is similar to BoxCox
CPI['cpi'] = CPI['cpi'] + .0001

# %%
CPI['log'] = np.log(CPI['cpi'])
CPI['YeoJohnson'], opt_lambda = yeojohnson(CPI['cpi'])

# %%
for col in CPI.columns:
    model_col = auto_arima(y=CPI[col], m=4, seasonal=True)
    print(f'================= {col} ==================')
    print(model_col.summary())
# Out:
# ================= cpi ==================
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                                 y   No. Observations:                  128
# Model:             SARIMAX(2, 1, 2)x(0, 0, 2, 4)   Log Likelihood                 -78.338
# Date:                           Wed, 11 Feb 2026   AIC                            170.675
# Time:                                   21:33:12   BIC                            190.585
# Sample:                               01-01-1994   HQIC                           178.764
#                                     - 10-01-2025
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8988      0.128      7.022      0.000       0.648       1.150
# ar.L2         -0.6211      0.111     -5.613      0.000      -0.838      -0.404
# ma.L1         -0.5400      0.096     -5.635      0.000      -0.728      -0.352
# ma.L2          0.8198      0.069     11.946      0.000       0.685       0.954
# ma.S.L4       -0.2061      0.070     -2.942      0.003      -0.343      -0.069
# ma.S.L8       -0.6234      0.065     -9.611      0.000      -0.751      -0.496
# sigma2         0.1912      0.024      7.951      0.000       0.144       0.238
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.43   Jarque-Bera (JB):                14.85
# Prob(Q):                              0.51   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.58   Skew:                             0.42
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.45
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ================= log ==================
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  128
# Model:               SARIMAX(1, 0, 1)   Log Likelihood                -129.618
# Date:                Wed, 11 Feb 2026   AIC                            267.236
# Time:                        21:33:15   BIC                            278.644
# Sample:                    01-01-1994   HQIC                           271.871
#                          - 10-01-2025
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.2182      0.244      0.895      0.371      -0.260       0.696
# ar.L1          0.5945      0.047     12.563      0.000       0.502       0.687
# ma.L1          0.9416      0.046     20.464      0.000       0.851       1.032
# sigma2         0.4317      0.025     17.087      0.000       0.382       0.481
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):             15466.99
# Prob(Q):                              0.80   Prob(JB):                         0.00
# Heteroskedasticity (H):              15.72   Skew:                            -6.08
# Prob(H) (two-sided):                  0.00   Kurtosis:                        55.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ================= YeoJohnson ==================
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                                 y   No. Observations:                  128
# Model:             SARIMAX(3, 0, 0)x(2, 0, 0, 4)   Log Likelihood                  90.892
# Date:                           Wed, 11 Feb 2026   AIC                           -167.784
# Time:                                   21:33:19   BIC                           -147.820
# Sample:                               01-01-1994   HQIC                          -159.672
#                                     - 10-01-2025
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.1087      0.047      2.306      0.021       0.016       0.201
# ar.L1          1.2635      0.105     12.043      0.000       1.058       1.469
# ar.L2         -0.1163      0.148     -0.787      0.431      -0.406       0.173
# ar.L3         -0.2090      0.086     -2.418      0.016      -0.378      -0.040
# ar.S.L4       -0.4109      0.091     -4.538      0.000      -0.588      -0.233
# ar.S.L8       -0.2958      0.101     -2.933      0.003      -0.494      -0.098
# sigma2         0.0137      0.002      9.063      0.000       0.011       0.017
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                39.62
# Prob(Q):                              0.88   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.43   Skew:                            -0.53
# Prob(H) (two-sided):                  0.25   Kurtosis:                         5.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### **Fitting Forecast**

# %%
yeo = auto_arima(y= CPI['YeoJohnson'],m=4,seasonal=True)

# %%
# Inverse Yeo-Johnson transformation
def inv_yeojohnson(y, lmbda):
    """Inverse Yeo-Johnson transformation"""
    y = np.asarray(y)
    inv = np.zeros_like(y)
    pos = y >= 0
    
    if lmbda != 0:
        inv[pos] = np.power(y[pos] * lmbda + 1, 1 / lmbda) - 1
    else:
        inv[pos] = np.exp(y[pos]) - 1
    
    if lmbda != 2:
        inv[~pos] = 1 - np.power(-(2 - lmbda) * y[~pos] + 1, 1 / (2 - lmbda))
    else:
        inv[~pos] = 1 - np.exp(-y[~pos])
    
    return inv

forecast_yeo = yeo.predict(n_periods=16)
forecast_from_yeo = inv_yeojohnson(forecast_yeo, opt_lambda)

if not isinstance(CPI.index, pd.DatetimeIndex):
    print("Converting CPI index to datetime...")
    CPI.index = pd.to_datetime(CPI.index)

# Create forecast index with proper datetime handling
last_date = CPI.index[-1]

# Create forecast dates
forecast_index = pd.date_range(
    start=last_date + pd.DateOffset(months=3),  # Start from next quarter
    periods=16, 
    freq='QE'
)


plt.figure(figsize=(14, 8))
recent_data = CPI['cpi'].iloc[-40:]

# Plot with converted indices
plt.plot(recent_data.index, recent_data.values, label='Historical', linewidth=2)
plt.plot(forecast_index, forecast_from_yeo, label='Forecast (Yeo-Johnson Transform)', 
         linewidth=2, color='purple', marker='o', markersize=8)
plt.title('CPI Forecast - Yeo-Johnson Transformation')
plt.ylabel('CPI')
plt.xlabel('Date')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Last date: 2025-10-01 00:00:00, Type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# Forecast index: DatetimeIndex(['2026-03-31', '2026-06-30', '2026-09-30', '2026-12-31',
#                '2027-03-31', '2027-06-30', '2027-09-30', '2027-12-31',
#                '2028-03-31', '2028-06-30', '2028-09-30', '2028-12-31',
#                '2029-03-31', '2029-06-30', '2029-09-30', '2029-12-31'],
#               dtype='datetime64[ns]', freq='QE-DEC')

# %% [markdown]
# # **US Manual Modeling:**

# %%
y = df_US['us_delinquency_rate']

# %% [markdown]
# We will run checks of stationarity, then use Log, Neo-Johnson & Box-Cox transformations. We will induvidually look at the ACF & PACF plots in determinining lags
